# %% [markdown]
# <a href="https://colab.research.google.com/github/dvgba/10_10_Github-Profile/blob/master/CTM___Ensaio_Massa_Saturada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -- Monte Belo  T06

import pandas as pd
import matplotlib.pyplot as plt

# Dados das amostras
amostrasMb = [[375.8, 435.15, 389.35],
            [385.69, 449.74, 395.94], 
            [408.23, 473.52, 421.48], 
            [474.22, 416.30, 418.02], 
            [478.31, 407.69, 426.40], 
            [476.76, 408.71, 424.95]]


# Plotando o gráfico 
df = pd.DataFrame(amostrasMb, columns=['MB1', 'MB2', 'MB3'], index=['07/04', '10/04','17/04', '19/04', '25/04', '28/04'])

df.plot(kind='line')
plt.title('Variação das amostras, usando a Proveta')
plt.xlabel('Dia')
plt.ylabel('Volume (cm³)')
plt.grid()

plt.show()
print('------ Massa Saturada -------')
print('-----------------------------')
print(df)
# Out:
# ------ Massa Saturada -------
# -----------------------------
#           MB1     MB2     MB3
# 07/04  375.80  435.15  389.35
# 10/04  385.69  449.74  395.94
# 17/04  408.23  473.52  421.48
# 19/04  474.22  416.30  418.02
# 25/04  478.31  407.69  426.40
# 28/04  476.76  408.71  424.95

# %%
# -- Santa Rita  T09

import pandas as pd
import matplotlib.pyplot as plt

# Dados das amostras
amostrasSt = [[195.29, 223.64, 199.25],
              [338.01, 292.47, 326.63],
              [358.86, 316.35, 356.51], 
              [366.03, 321.53, 358.49], 
              [367.42, 323.30, 362.00], 
              [367.02, 323.35, 364.14], 
              [367.68, 323.87, 363.83]]


# Plotando o gráfico 
df = pd.DataFrame(amostrasSt, columns=['St1', 'St2', 'St3'], index=['04/04', '07/04', '10/04','13/04', '16/04', '19/04', '22/04'])

df.plot(kind='line')
plt.title('Variação das amostras, usando a Proveta')
plt.xlabel('Dia')
plt.ylabel('Volume (cm³)')
plt.grid()

plt.show()
print('------ Massa Saturada -------')
print('-----------------------------')
print(df)
# Out:
# ------ Massa Saturada -------
# -----------------------------
#           St1     St2     St3
# 04/04  195.29  223.64  199.25
# 07/04  338.01  292.47  326.63
# 10/04  358.86  316.35  356.51
# 13/04  366.03  321.53  358.49
# 16/04  367.42  323.30  362.00
# 19/04  367.02  323.35  364.14
# 22/04  367.68  323.87  363.83

# %%
# -- Santa Rita  T09

import pandas as pd
import matplotlib.pyplot as plt

# Dados das amostras
amostrasSt = [[217.74, 193.28, 210.68],
              [338.01, 292.47, 326.63],
              [358.86, 316.35, 356.51], 
              [366.03, 321.53, 358.49], 
              [367.42, 323.30, 362.00], 
              [367.02, 323.35, 364.14], 
              [367.68, 323.87, 363.83]]


# Plotando o gráfico 
df = pd.DataFrame(amostrasSt, columns=['St1', 'St2', 'St3'], index=['04/04', '07/04', '10/04','13/04', '16/04', '19/04', '22/04'])

df.plot(kind='line')
plt.title('Variação das amostras')
plt.xlabel('Dia')
plt.ylabel('Volume (cm³)')
plt.grid()

plt.show()
print('------ Massa Saturada -------')
print('-----------------------------')
print(df)
# Out:
# ------ Massa Saturada -------
# -----------------------------
#           St1     St2     St3
# 04/04  217.74  193.28  210.68
# 07/04  338.01  292.47  326.63
# 10/04  358.86  316.35  356.51
# 13/04  366.03  321.53  358.49
# 16/04  367.42  323.30  362.00
# 19/04  367.02  323.35  364.14
# 22/04  367.68  323.87  363.83

# %%
# -- Amostra Monte Belo T08


import pandas as pd
import matplotlib.pyplot as plt

# Adiciona as medições do dia
dadosimersao = [[177.56, 164.06, 148.46],
                [335.36, 313.60, 291.28],
                [359.05, 338.87, 308.19],
                [392.83, 360.23, 332.4],
                [378.06, 347.89, 314.81],
                [376.15, 356.39, 318.37],
                [355.13, 376.94, 327.84],
                [377.89, 352.92, 319.94]]

# Configuração do gráfico
df = pd.DataFrame(dadosimersao, columns=['MBLT1', 'MBLT2', 'MBLT3'], index=['07/04', '10/04', '13/04','16/04', '19/04', '22/04', '25/04', '28/04'])

# Configuração do gráfico
df.plot(kind='line')
plt.title('Variação de volume das amostras, usando a Imersão')
plt.xlabel('Dia')
plt.ylabel('Volume (cm³)')
plt.grid()

# Exibição do gráfico
plt.show()

# Exibição do Dataframe
print('------ Massa Saturada -------')
print('-----------------------------')
print(df)
# Out:
# ------ Massa Saturada -------
# -----------------------------
#         MBLT1   MBLT2   MBLT3
# 07/04  177.56  164.06  148.46
# 10/04  335.36  313.60  291.28
# 13/04  359.05  338.87  308.19
# 16/04  392.83  360.23  332.40
# 19/04  378.06  347.89  314.81
# 22/04  376.15  356.39  318.37
# 25/04  355.13  376.94  327.84
# 28/04  377.89  352.92  319.94
